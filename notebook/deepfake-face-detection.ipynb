# %%
import warnings
warnings.filterwarnings("ignore")

# !pip install matplotlib
# !pip install evaluate
# !pip install scikit-learn
# !pip install imbalanced-learn
# !pip install accelerate
# !pip install transformers
# !pip install torch torchvision torchaudio


import gc
import numpy as np
import pandas as pd
import itertools #for iteration and looping
from collections import Counter #to count element
import matplotlib.pyplot as plt

from sklearn.metrics import(
    accuracy_score, #accuracy calculation
    roc_auc_score,#for roc auc score
    confusion_matrix,
    classification_report,
    f1_score
)

#custom modules and classes
from imblearn.over_sampling import RandomOverSampler
import accelerate
import evaluate
from datasets import Dataset,Image,ClassLabel
from transformers import(
    TrainingArguments,
    Trainer,
    ViltImageProcessor,
    ViTForImageClassification,
    DefaultDataCollator
)

import torch  #pytorch for deeplearning
from torch.utils.data import DataLoader
from torchvision.transforms import (
    CenterCrop, #center cops an image
    Compose, #composes multiple image transformation
    Normalize, #normalizes image picture values
    RandomRotation,
    RandomResizedCrop,
    RandomHorizontalFlip,
    RandomAdjustSharpness,
    Resize,
    ToTensor #convert image to pytorch tensor
)
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------------- ---------------------- 3.4/8.0 MB 17.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.0 MB 18.1 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 8.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 6.6 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/36.3 MB ? eta -:--:--
#     --------------------------------------- 0.8/36.3 MB 6.3 MB/s eta 0:00:06
#    -- ------------------------------------- 2.4/36.3 MB 6.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 3.9/36.3 MB 6.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 4.7/36.3 MB 5.9 MB/s eta 0:00:06
# ...

# %%
#python image library 
from PIL import Image

#Enable the option to load truncated images #to get corruppted images to load
Image.LOAD_TRUNCATED_IMAGES = True

# %%
# !pip install kaggle
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 12.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.9/10.1 MB 16.9 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/10.1 MB 9.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.2/10.1 MB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.0/10.1 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 6.3/10.1 MB 5.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.1/10.1 MB 5.7 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.1 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 5.5 MB/s eta 0:00:01
# ...

# %%
#KGAT_75ef31e5244466b5035e047834f0fa76
export pip install kaggle

# %%
Image_Dict={}

from pathlib import Path
from tqdm import tqdm
import os

file_name=[]
labels=[]

for file in sorted((Path('')))
    label =str(file).split('/')[-2]
    labels.append(label)
    file_name.append(str(file))


print(len(file_name),len(labels))

df=pd.DataFrame.from_dict({"image":file_name,"label":labels})
print(df. shape)
